# %% [markdown]
# # Evaluation Learning
# In order to find the best evaluation function, we try to analyze the data

# %% [markdown]
# ## Step 1 dimensionality reduction PCA vs t-SNE
#
# 1.  PCA
# 2.  t-SNE

# %% [markdown]
# ### baisc example

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Apply PCA for 2 components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Visualize the PCA results
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Iris dataset')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.manifold import TSNE

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Apply t-SNE for 2 components
tsne = TSNE(n_components=2, perplexity=30, n_iter=300)
X_tsne = tsne.fit_transform(X)

# Visualize the t-SNE results
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.title('t-SNE of Iris dataset')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

def convert_duration_to_flot(df):
    for col_have_days in ['Duration', 'Max. Trade Duration', 'Max. Drawdown Duration', 'Avg. Drawdown Duration', 'Avg. Trade Duration']:
        df[col_have_days] = df[col_have_days].str.replace(' days', '').astype(float)

    return df

# Read the CSV file
runs = pd.read_csv("runAll.csv").drop(['_strategy', '_equity_curve', 'Unnamed: 26'], axis=1)

runs = convert_duration_to_flot(runs)

# View the first 5 rows
runs.head()
runs.dropna(inplace=True)  # Drops rows with NaN values

# Apply PCA for 2 components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(runs)

# # Visualize the PCA results
plt.scatter(X_pca[:, 0], X_pca[:, 1], cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA runAll')
# Out:
# C:\Users\eviatar\AppData\Local\Temp\ipykernel_4988\235864732.py:28: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X_pca[:, 0], X_pca[:, 1], cmap='viridis')
# Text(0.5, 1.0, 'PCA runAll')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def convert_duration_to_flot(df):
    for col_have_days in ['Duration', 'Max. Trade Duration', 'Max. Drawdown Duration', 'Avg. Drawdown Duration', 'Avg. Trade Duration']:
        df[col_have_days] = df[col_have_days].str.replace(' days', '').astype(float)

    return df

# Read the CSV file
runs = pd.read_csv("runAll.csv").drop(['_strategy', '_equity_curve', 'Unnamed: 26'], axis=1)

runs = convert_duration_to_flot(runs)

tsne = TSNE(n_components=2, perplexity=35, n_iter=300)
X_tsne = tsne.fit_transform(X)

# Visualize the t-SNE results
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.title('t-SNE of runs dataset')
plt.show()

# %%
def plot_2_colm(col_1, col_2):
    plt.scatter(runs[col_1], runs[col_2], cmap='viridis')
    plt.xlabel(col_1)
    plt.ylabel(col_2)
    plt.show()


plot_2_colm('Return [%]', 'Win Rate [%]')
plot_2_colm('Best Trade [%]', 'Win Rate [%]')
plot_2_colm('Best Trade [%]', 'Worst Trade [%]')
# Out:
# C:\Users\eviatar\AppData\Local\Temp\ipykernel_4988\784078240.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(runs[col_1], runs[col_2], cmap='viridis')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

def convert_duration_to_flot(df):
    for col_have_days in ['Duration', 'Max. Trade Duration', 'Max. Drawdown Duration', 'Avg. Drawdown Duration', 'Avg. Trade Duration']:
        df[col_have_days] = df[col_have_days].str.replace(' days', '').astype(float)

    return df

# Read the CSV file
runs = pd.read_csv("runAll.csv").drop(['_strategy', '_equity_curve', 'Unnamed: 26'], axis=1)

runs = convert_duration_to_flot(runs)
win_return = runs['Return [%]', 'Win Rate [%]', 'Best Trade [%]', 'Worst Trade [%]']
# View the first 5 rows
win_return.head()
win_return.dropna(inplace=True)  # Drops rows with NaN values

# Apply PCA for 2 components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(win_return)

# # Visualize the PCA results
plt.scatter(X_pca[:, 0], X_pca[:, 1], cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA runAll')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\eviatar\anaconda3\envs\algoTride\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\eviatar\anaconda3\envs\algoTride\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\eviatar\anaconda3\envs\algoTride\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Return [%]', 'Win Rate [%]', 'Best Trade [%]', 'Worst Trade [%]')
#
# ...

# %%
import inspect

baz = [2, 3, lambda x, y: x / y, 5]
print(inspect.getsource(baz[2]))
# Out:
# baz = [2, 3, lambda x, y: x / y, 5]

# %%
import inspect

class C:
    def __init__(self, rec_func=None):
        self.rec_func = rec_func if rec_func else lambda data: data

c = C(rec_func=lambda data: data * 2)
print(inspect.getsource(c.rec_func))
# Out:
# c = C(rec_func=lambda data: data * 2)
